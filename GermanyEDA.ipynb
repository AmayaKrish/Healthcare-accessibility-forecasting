# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
germany = pd.read_csv(r"C:/Users/Admin/Germany_Healthcare_Data.csv")

# %%
germany.head()
germany.info()
germany.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             35 non-null     int64
#  1   Country                          35 non-null     object
#  2   Infant_Mortality                 35 non-null     float64
#  3   GDP_per_Capita                   35 non-null     float64
#  4   Urban_Population                 35 non-null     float64
#  5   Total_Population                 35 non-null     float64
#  6   Obesity_Prevalence               35 non-null     float64
#  7   Cardiovascular_Deaths_Rate       35 non-null     float64
#  8   Chronic_Respiratory_Deaths_Rate  35 non-null     float64
#  9   Diabetes_Deaths_Rate             35 non-null     float64
#  10  Neoplasms_Deaths_Rate            35 non-null     float64
#  11  UHC_Coverage_Index               35 non-null     float64
# ...
